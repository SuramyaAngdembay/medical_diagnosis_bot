# %%
ls
# Out:
# release_conditions.json     release_train_patients.zip
# release_evidences.json      release_validate_patients.csv
# release_test_patients.csv   release_validate_patients.zip
# release_test_patients.zip   Untitled.ipynb
# release_train_patients.csv

# %%
import pandas as pd
df = pd.read_csv("release_train_patients.csv",nrows=1000)

# %%
df
# Out:
#      AGE                             DIFFERENTIAL_DIAGNOSIS SEX  \
# 0     18  [['Bronchitis', 0.19171203430383882], ['Pneumo...   M
# 1     21  [['HIV (initial infection)', 0.518950056440760...   M
# 2     19  [['Bronchitis', 0.11278064619119596], ['Pneumo...   F
# 3     34  [['URTI', 0.23859396799565236], ['Cluster head...   F
# 4     36  [['URTI', 0.23677812769175735], ['Influenza', ...   M
# ..   ...                                                ...  ..
# 995   19  [['Sarcoidosis', 0.3660373542668306], ['Acute ...   F
# 996   38  [['Epiglottitis', 0.1645377008773267], ['Laryg...   M
# 997   44  [['Inguinal hernia', 0.2852835237477805], ['Br...   M
# 998   17  [['PSVT', 0.15649215256819674], ['Panic attack...   M
# 999    3  [['Acute otitis media', 0.37353425270355334], ...   M
#
#                    PATHOLOGY  \
# 0                       URTI
# 1    HIV (initial infection)
# 2                  Pneumonia
# 3                       URTI
# 4                       URTI
# ...

# %%
   # 1. Basic Features
   - Age (normalized)
   - Sex (one-hot encoded)
   - Initial evidence (one-hot encoded)
   
   # 2. Evidence-based Features
   - Binary evidence counts
   - Categorical evidence distributions
   - Multi-choice evidence combinations
   
   # 3. Derived Features
   - Age groups (binned)
   - Evidence co-occurrence patterns
   - Evidence frequency in training data
   - Evidence importance scores
