# %% [markdown]
# <a href="https://colab.research.google.com/github/SuramyaAngdembay/medical_diagnosis_bot/blob/chatbot-rl-integration/RL_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# sample_data/
